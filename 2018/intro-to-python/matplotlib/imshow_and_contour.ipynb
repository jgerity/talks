# %%
import numpy as np
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt

matplotlib.rcParams['image.cmap'] = 'viridis'

# %% [markdown]
# **`plt.imshow()` can be used to encode array data as individual pixels**

# %%
numx = 10
numy = 30
img = 255*np.random.normal(size=(numx, numy))
img[0:10, 0:10] = 0
plt.imshow(img, cmap='gray')

# %% [markdown]
# **The `ndarray.reshape` method might sometimes be helpful when doing so.  The `order` parameter determines the order in which array axes are read when doing this reshaping.**

# %%
plt.subplot(121)
plt.imshow(img2, cmap='gray')
img2 = img.reshape((numx*2, numy/2))

plt.subplot(122)
plt.imshow(img3, cmap='gray')
img3 = img.reshape((numx*2, numy/2), order='F')

# %% [markdown]
# **The `numpy.meshgrid` method is frequently helpful when plotting functions of multiple variables.  Remember, an `ndarray` is just a string of numbers in memory!  What `meshgrid` is doing is arranging the **

# %%
x = np.arange(-100, 100)
y = np.arange(-100, 100)
X,Y = np.meshgrid(x,y)
print(x.shape, X.shape, Y.shape)
Z = np.sqrt(X**2 + Y**2)

plt.contourf(X, Y, Z, levels=np.linspace(Z.min(), Z.max(), 10))
plt.colorbar()
# Out:
# ((200,), (200, 200), (200, 200))

# %%
plt.imshow(Z, vmin=-1, vmax=100, extent=[-100,100,-100,100])
plt.colorbar()
