# %% [markdown]
# **Most of this is stolen from the [seaborn tutorial](https://stanford.edu/~mwaskom/software/seaborn/tutorial.html)**

# %%
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %% [markdown]
# **Here's a default matplotlib plot.  It's nice, but it's boring, and the default color style really isn't all that legible...**

# %%
sinplot()

# %% [markdown]
# **We can tweak all kinds of things, but it can get tedious, as we've seen.  Let's import seaborn to get some easy themes.**

# %%
import seaborn as sns

# %%
sinplot()

# %% [markdown]
# **This is the `darkgrid` theme.  Also available are `whitegrid, white, ticks`.**

# %%
sns.set_style("white")
sinplot()
plt.figure()
sinplot()
sns.despine()

# %% [markdown]
# **Of course, seaborn doesn't just look nice, it has useful methods!  Boxplots are frequently useful for 1D statistics at a glance, and we can produce them with very little work!**

# %%
# create 10 sets of samples of a normal distribution, 100 apiece.
data = np.random.normal(size=(100,10))
sns.boxplot(data=data)

# %% [markdown]
# **How about using one of those sweet colormaps from before?**

# %%
sns.boxplot(data=data, palette='viridis')

# %% [markdown]
# **Well, what if I don't like viridis?**

# %%
sns.boxplot(data=data, palette='jet')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-9-bfd82fb75e43> in <module>()
# ----> 1 sns.boxplot(data=data, palette='jet')
#
# /home/vagrant/.pyenv/versions/2.7.10/lib/python2.7/site-packages/seaborn/categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# /home/vagrant/.pyenv/versions/2.7.10/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
#     425
#     426         self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 427         self.establish_colors(color, palette, saturation)
#     428
#     429         self.width = width
#
# /home/vagrant/.pyenv/versions/2.7.10/lib/python2.7/site-packages/seaborn/categorical.pyc in establish_colors(self, color, palette, saturation)
#     293                 palette = [palette[l] for l in levels]
#     294
# --> 295             colors = color_palette(palette, n_colors)
#     296
#     297         # Desaturate a bit because these are patches
#
# /home/vagrant/.pyenv/versions/2.7.10/lib/python2.7/site-packages/seaborn/palettes.pyc in color_palette(palette, n_colors, desat)
#     170             palette = husl_palette(n_colors)
#     171         elif palette.lower() == "jet":
# --> 172             raise ValueError("No.")
#     173         elif palette in SEABORN_PALETTES:
#     174             palette = SEABORN_PALETTES[palette]
#
# ValueError: No.

# %% [markdown]
# **How about a bar plot?**

# %%
sns.barplot(data=data)

# %% [markdown]
# **On second thought, not crazy about those confidence intervals...**

# %%
sns.barplot(data=data, ci=None)

# %% [markdown]
# **Frequently, we want to check out a distribution.  The `distplot()` routine gives us a nice auto-binned histogram and a kernel density estimate.**

# %%
Nsamples = 100
data = np.random.normal(size=Nsamples)
sns.distplot(data)

# %% [markdown]
# **Of course, we shouldn't just trust this binning.  Let's enable `rugplot` to show the actual data along with the bins.  And let's turn off the density estimate until we do The Right Thing™ and read the docs to understand exactly what it's doing...**

# %%
sns.distplot(data, rug=True, kde=False)

# %% [markdown]
# **If we have multivariate data, seaborn's got our back.**

# %%
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200).reshape(2,200)

sns.jointplot(x=data[0, :], y=data[1, :])

# %% [markdown]
# **Even if we'd rather see our data binned.**

# %%
sns.jointplot(x=data[0, :], y=data[1, :], kind='hex')
plt.colorbar()
